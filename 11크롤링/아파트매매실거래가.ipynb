# %% [markdown]
# ### 공공데이터 포털 아파트 실거래가 API 실습
# API란?<br>
# 서버가 데이터를 JSON/XML형식으로 내려주는 통로<br>
# 우리가 할 일<br>
# - 요청 URL 생성( 신청 - 서비스키 발급 )<br>
# - 파라미터 설정<br>
# - 응답( JSON/XML )<br>
# - 파싱 -> 데이터 정리<br>

# %%
# %pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
url = 'https://apis.data.go.kr/1613000/RTMSDataSvcAptTrade/getRTMSDataSvcAptTrade?serviceKey=9f282952ff8ab4fe8b27b30afc417a77330f14feb6a50210037371edfe471dbd&LAWD_CD=11110&DEAL_YMD=202407&pageNo=1&numOfRows=1'

res = requests.get(url)
print(res.status_code)    # 응답코드
print(res.text[:500])     # slicing
# Out:
# 200
# <?xml version="1.0" encoding="utf-8" standalone="yes"?><response><header><resultCode>000</resultCode><resultMsg>OK</resultMsg></header><body><items><item><aptDong>107</aptDong><aptNm>인왕산아이파크</aptNm><buildYear>2008</buildYear><buyerGbn>개인</buyerGbn><cdealDay> </cdealDay><cdealType> </cdealType><dealAmount>143,500</dealAmount><dealDay>17</dealDay><dealMonth>7</dealMonth><dealYear>2024</dealYear><dealingGbn>중개거래</dealingGbn><estateAgentSggNm>서울 종로구</estateAgentSggNm><excluUseAr>114.931</excluUseAr>
