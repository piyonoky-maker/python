# %% [markdown]
# ## 공공데이터 포털 OPEN API 사용하기
# ### step1: 학습목표
# OPEN API 사용하여 데이터 수집하기<br>
# 1. 공공데이터 포털 회원가입/ 로그인( http://www.data.go.kr ) <br>
# 2. API 사용 요청/ 키발급<br>
# 3. API 문서 확인<br>
# 4. API 테스트 및 개발

# %% [markdown]
# step2: EndPoint확인하기
# - API가 서비스 되는 서비스의 IP 혹은 domain주소

# %%
import requests
BASE_URL = "https://api.odcloud.kr/api/15134550/v1/uddi:1ef33027-87bc-44c0-b7f0-e772dac192e8?page=1&perPage=10&returnType=json&serviceKey=data-portal-test-key"

res = requests.get(BASE_URL, timeout = 10)
print("status : ", res.status_code)
# Out:
# status :  200

# %%
print(res.json())
# Out:
# {'currentCount': 10, 'data': [{'기준_날짜': '2024-08-21', '승객_수': 1047562, '승차_승객_수': 527162, '하차_승객_수': 520400, '호선_명칭': '3호선'}, {'기준_날짜': '2024-08-21', '승객_수': 1043161, '승차_승객_수': 515752, '하차_승객_수': 527409, '호선_명칭': '4호선'}, {'기준_날짜': '2024-08-21', '승객_수': 667607, '승차_승객_수': 336194, '하차_승객_수': 331413, '호선_명칭': '6호선'}, {'기준_날짜': '2024-08-21', '승객_수': 319239, '승차_승객_수': 160216, '하차_승객_수': 159023, '호선_명칭': '경부선'}, {'기준_날짜': '2024-08-21', '승객_수': 2863665, '승차_승객_수': 1417030, '하차_승객_수': 1446635, '호선_명칭': '2호선'}, {'기준_날짜': '2024-08-21', '승객_수': 465485, '승차_승객_수': 235840, '하차_승객_수': 229645, '호선_명칭': '1호선'}, {'기준_날짜': '2024-08-21', '승객_수': 24046, '승차_승객_수': 11728, '하차_승객_수': 12318, '호선_명칭': '별내선'}, {'기준_날짜': '2024-08-21', '승객_수': 1184, '승차_승객_수': 625, '하차_승객_수': 559, '호선_명칭': '장항선'}, {'기준_날짜': '2024-08-21', '승객_수': 211283, '승차_승객_수': 107699, '하차_승객_수': 103584, '호선_명칭': '경원선'}, {'기준_날짜': '2024-08-21', '승객_수': 61864, '승차_승객_수': 31107, '하차_승객_수': 30757, '호선_명칭': '신림선'}], 'matchCount': 100, 'page':
# ...

# %%
print(res.json()['data'])
# Out:
# [{'기준_날짜': '2024-08-21', '승객_수': 1047562, '승차_승객_수': 527162, '하차_승객_수': 520400, '호선_명칭': '3호선'}, {'기준_날짜': '2024-08-21', '승객_수': 1043161, '승차_승객_수': 515752, '하차_승객_수': 527409, '호선_명칭': '4호선'}, {'기준_날짜': '2024-08-21', '승객_수': 667607, '승차_승객_수': 336194, '하차_승객_수': 331413, '호선_명칭': '6호선'}, {'기준_날짜': '2024-08-21', '승객_수': 319239, '승차_승객_수': 160216, '하차_승객_수': 159023, '호선_명칭': '경부선'}, {'기준_날짜': '2024-08-21', '승객_수': 2863665, '승차_승객_수': 1417030, '하차_승객_수': 1446635, '호선_명칭': '2호선'}, {'기준_날짜': '2024-08-21', '승객_수': 465485, '승차_승객_수': 235840, '하차_승객_수': 229645, '호선_명칭': '1호선'}, {'기준_날짜': '2024-08-21', '승객_수': 24046, '승차_승객_수': 11728, '하차_승객_수': 12318, '호선_명칭': '별내선'}, {'기준_날짜': '2024-08-21', '승객_수': 1184, '승차_승객_수': 625, '하차_승객_수': 559, '호선_명칭': '장항선'}, {'기준_날짜': '2024-08-21', '승객_수': 211283, '승차_승객_수': 107699, '하차_승객_수': 103584, '호선_명칭': '경원선'}, {'기준_날짜': '2024-08-21', '승객_수': 61864, '승차_승객_수': 31107, '하차_승객_수': 30757, '호선_명칭': '신림선'}]
